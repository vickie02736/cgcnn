# %%
import pandas as pd

filename = '/home/uceckz0/Project/cgcnn/qmof_database/qmof_target.csv'
df = pd.read_csv(filename)
df
# Out:
#             qmof_id                                    name  info.pld  \
# 0      qmof-8a95c27                            ABACUF01_FSR   0.68822
# 1      qmof-019ba28                              ABALOF_FSR   1.18570
# 2      qmof-830ed1c                              ABAVIJ_FSR   2.36128
# 3      qmof-5bd4a24                              ABAVOP_FSR   2.14542
# 4      qmof-644aab4                              ABAXUZ_FSR   1.33452
# ...             ...                                     ...       ...
# 20370  qmof-7aebbbb  tobacco_srsb_sym_3_on_2_sym_3_mc_0_L_2  19.56940
# 20371  qmof-9a04c15  tobacco_srsb_sym_3_on_2_sym_3_mc_0_L_6  20.80552
# 20372  qmof-0dce90f    tobacco_srsb_sym_3_on_2_sym_3_mc_0__  10.86124
# 20373  qmof-955fe88  tobacco_srsb_sym_3_on_4_sym_3_mc_0_L_2  23.17582
# 20374  qmof-6538047  tobacco_srsb_sym_3_on_5_sym_3_mc_0_L_2  23.34456
#
#        info.lcd  info.density   info.volume  outputs.pbe.energy_total  \
# ...

# %%
qmof_id = df["qmof_id"]
qmof_outputs_pbe_bandgap = df["outputs.pbe.bandgap"]

# %%
new_df = pd.concat([qmof_id, qmof_outputs_pbe_bandgap], axis=1)

# %%
new_df.shape
# Out:
# (20375, 2)

# %%
new_df.to_csv('id_prop.csv', index=False, header=False)
