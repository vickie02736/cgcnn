# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../jobs/output/test_results.csv')

# %%
plt.scatter(df.iloc[:,1], df.iloc[:,2], marker="o", color="blue", s=10)
plt.title('Test Results')
# Out:
# Text(0.5, 1.0, 'Test Results')
